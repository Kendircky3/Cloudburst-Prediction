# %%
# !pip install xarray cfgrib pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 2.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import xarray as xr

# Load the GRIB file
file_path = '/Users/yu/Desktop/Weather Data/d2a046e512656ea918d40f8ee3d9d4fb.grib'
ds = xr.open_dataset(file_path, engine='cfgrib')

# Print all variable names and their shapes
for var in ds.data_vars:
    print(f"{var}: {ds[var].dims}, dtype={ds[var].dtype}")
# Out:
# skipping variable: paramId==228 shortName='tp'
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/cfgrib/dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/opt/anaconda3/lib/python3.12/site-packages/cfgrib/dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='time' value=Variable(dimensions=('time',), data=array([1640995200, 1640998800, 1641002400, 1641006000, 1641009600,
#        1641013200, 1641016800, 1641020400, 1641024000, 1641027600,
#        1641031200, 1641034800, 1641038400, 1641042000, 1641045600,
#        1641049200, 1641052800, 1641056400, 1641060000, 1641063600,
#        1641067200, 1641070800, 1641074400, 1641078000, 1641081600,
#        1641085200, 1641088800, 1641092400, 1641096000, 1641099600,
#        1641103200, 1641106800, 1641110400, 1641114000, 1641117600,
# ...

# %%
# Convert the entire dataset into a pandas DataFrame
df = ds.to_dataframe().reset_index()

# Display the first few rows
df.head()
# Out:
#         time  latitude  longitude  number   step  surface valid_time  \
# 0 2023-01-01      31.0     -87.70       0 0 days      0.0 2023-01-01
# 1 2023-01-01      31.0     -87.45       0 0 days      0.0 2023-01-01
# 2 2023-01-01      31.0     -87.20       0 0 days      0.0 2023-01-01
# 3 2023-01-01      31.0     -86.95       0 0 days      0.0 2023-01-01
# 4 2023-01-01      31.0     -86.70       0 0 days      0.0 2023-01-01
#
#         u10       v10         d2m         t2m            sp
# 0  0.170797  2.576016  290.711182  291.767822  100942.78125
# 1  0.426901  2.367520  290.674805  291.940186  100816.78125
# 2  0.578268  2.228360  290.617920  292.130859  100855.96875
# 3  0.656881  2.160977  290.425049  292.300293  100942.56250
# 4  0.646627  2.139737  290.203857  292.439453  100875.15625
